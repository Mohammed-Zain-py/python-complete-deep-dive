# %% [markdown]
# # Python Complete Deep Dive
#
# ## Day 6 — String Methods in Python
#
# In this notebook, we will cover:
#
# * Common string methods
# * Useful operations on strings
# * Practice problems using string methods

# %% [markdown]
# # What are String Methods?
#
# String methods are built-in functions that help us **perform operations on strings easily**.
#
# They are called using:
#
# string.method()

# %% [markdown]
# # Changing Case

# %%
text = "python programming"

print(text.upper())   # PYTHON PROGRAMMING
print(text.lower())   # python programming
print(text.title())   # Python Programming
print(text.capitalize())  # Python programming
# Out:
# PYTHON PROGRAMMING
# python programming
# Python Programming
# Python programming

# %% [markdown]
# # Removing Spaces

# %%
text = "   Python   "

print(text.strip())     # removes both sides
print(text.lstrip())    # left side
print(text.rstrip())    # right side
# Out:
# Python
# Python
#    Python

# %% [markdown]
# # Searching in Strings

# %%
text = "Python Programming"

print(text.find("Pro"))   # index of first occurrence
print(text.count("m"))    # count occurrences
print(text.startswith("Python"))
print(text.endswith("ing"))
# Out:
# 7
# 2
# True
# True

# %% [markdown]
# # Replacing Text

# %%
text = "I like Java"

print(text.replace("Java", "Python"))
# Out:
# I like Python

# %% [markdown]
# # Splitting and Joining

# %%
text = "Python is easy to learn"

words = text.split()
print(words)

new_text = "-".join(words)
print(new_text)
# Out:
# ['Python', 'is', 'easy', 'to', 'learn']
# Python-is-easy-to-learn

# %% [markdown]
# # Checking String Content

# %%
text1 = "Python123"
text2 = "Python"

print(text1.isalnum())   # letters + numbers
print(text2.isalpha())   # only letters
print("123".isdigit())   # only digits
print(" ".isspace())     # space check
# Out:
# True
# True
# True
# True

# %% [markdown]
# # Practice Problems

# %%
# Problem 1: Convert string to uppercase

text = "hello world"
print(text.upper())
# Out:
# HELLO WORLD

# %%
# Problem 2: Remove spaces from both sides

text = "   python   "
print(text.strip())
# Out:
# python

# %%
# Problem 3: Count occurrences of 'a'

text = "banana"
print(text.count("a"))
# Out:
# 3

# %%
# Problem 4: Replace a word

text = "I love Java"
print(text.replace("Java", "Python"))
# Out:
# I love Python

# %%
# Problem 5: Split sentence into words

text = "Python is fun"
print(text.split())
# Out:
# ['Python', 'is', 'fun']

# %% [markdown]
# # Summary
#
# In this notebook, we learned:
#
# * Common string methods
# * Case conversion methods
# * Searching and replacing
# * Splitting and joining strings
# * Checking string content
# * Solved practice problems
#
# String methods are very useful in problem solving and DSA.

# %% [markdown]
# # NOTE :
#
# These are just the most used and important once u need know but there are 47 methods in total
