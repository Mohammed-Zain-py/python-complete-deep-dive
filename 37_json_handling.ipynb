# %% [markdown]
# # Python Complete Deep Dive
#
# ## Day 37 — JSON Handling in Python
#
# In this notebook, we will cover:
#
# * What is JSON
# * json module
# * Converting Python → JSON
# * Converting JSON → Python
# * Reading and writing JSON files

# %% [markdown]
# # What is JSON?
#
# JSON (JavaScript Object Notation) is a **lightweight data format** used to store and exchange data.
#
# It looks like a dictionary in Python.

# %% [markdown]
# # Importing JSON Module

# %%
import json

# %% [markdown]
# # Python → JSON (dumps)

# %%
data = {"name": "Zain", "age": 21}

json_data = json.dumps(data)

print(json_data)
print(type(json_data))
# Out:
# {"name": "Zain", "age": 21}
# <class 'str'>

# %% [markdown]
# # JSON → Python (loads)

# %%
json_data = '{"name": "Zain", "age": 21}'

data = json.loads(json_data)

print(data)
print(type(data))
# Out:
# {'name': 'Zain', 'age': 21}
# <class 'dict'>

# %% [markdown]
# # Writing JSON to File

# %%
data = {"name": "Zain", "age": 21}

with open("data.json", "w") as file:
    json.dump(data, file)

# %% [markdown]
# # Reading JSON from File

# %%
with open("data.json", "r") as file:
    data = json.load(file)

print(data)
# Out:
# {'name': 'Zain', 'age': 21}

# %% [markdown]
# # Practice Problems

# %%
# Problem 1: Convert dict to JSON

data = {"city": "Bangalore"}

print(json.dumps(data))
# Out:
# {"city": "Bangalore"}

# %%
# Problem 2: Convert JSON to dict

json_data = '{"x": 10}'

print(json.loads(json_data))
# Out:
# {'x': 10}

# %%
# Problem 3: Write JSON to file

data = {"course": "Python"}

with open("test.json", "w") as file:
    json.dump(data, file)

# %%
# Problem 4: Read JSON from file

with open("test.json", "r") as file:
    print(json.load(file))
# Out:
# {'course': 'Python'}

# %% [markdown]
# # Summary
#
# In this notebook, we learned:
#
# * What JSON is
# * dumps() and loads()
# * dump() and load() for files
# * Practical usage
#
# JSON is essential for working with APIs and data.
