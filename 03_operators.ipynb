# %% [markdown]
# # Python Complete Deep Dive
#
# ## Day 3 — Operators in Python
#
# In this notebook, we will cover:
#
# * Arithmetic Operators
# * Comparison Operators
# * Logical Operators
# * Assignment Operators
# * Practice Problems

# %% [markdown]
# # What are Operators?
#
# Operators are used to **perform operations on variables and values**.
#
# Example:

# %%
a = 10
b = 5

print(a + b)
# Out:
# 15

# %% [markdown]
# # Arithmetic Operators
#
# These operators are used to perform mathematical operations:
#
# * Addition        → +
# * Subtraction     → -
# * Multiplication  → *
# * Division        → /
# * Floor Division  → //
# * Modulus         → %
# * Exponential     → **

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Power: 1000

# %% [markdown]
# # Comparison Operators
#
# These operators compare two values and return True or False:
#
# * Equal to → ==
# * Not equal to → !=
# * Greater than → >
# * Less than → <
# * Greater than or equal to → >=
# * Less than or equal to → <=

# %%
a = 10
b = 5

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# # Logical Operators
#
# Logical operators are used to combine conditions:
#
# * and → True if both conditions are true
# * or → True if at least one condition is true
# * not → Reverses the result

# %%
a = 10
b = 5

print(a > 5 and b > 2)
print(a > 5 or b > 10)
print(not(a > b))
# Out:
# True
# True
# False

# %% [markdown]
# # Assignment Operators
#
# These operators are used to assign values:
#
# * = → Assign
# * += → Add and assign
# * -= → Subtract and assign
# * *= → Multiply and assign
# * /= → Divide and assign

# %%
x = 10

x += 5
print(x)

x -= 3
print(x)

x *= 2
print(x)

x /= 4
print(x)
# Out:
# 15
# 12
# 24
# 6.0

# %% [markdown]
# # Practice Problems

# %%
# Problem 1: Take two numbers and print their sum

a = 5
b = 7

print("Sum:", a + b)
# Out:
# Sum: 12

# %%
# Problem 2: Check if a number is greater than 10

num = 12

print(num > 10)
# Out:
# True

# %%
# Problem 3: Check if a number is even or odd

num = 8

print(num % 2 == 0)
# Out:
# True

# %% [markdown]
# # Summary
#
# In this notebook, we learned:
#
# * Arithmetic operators
# * Comparison operators
# * Logical operators
# * Assignment operators
# * Basic problem solving using operators
#
# This is important for writing conditions and solving problems in Python.
