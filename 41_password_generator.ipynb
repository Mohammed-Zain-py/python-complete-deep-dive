# %% [markdown]
# # Python Complete Deep Dive
#
# ## Day 41 — Project 1: Password Generator
#
# In this notebook, we will build:
#
# * A random password generator
# * Using letters, digits, and symbols
# * Customizable password length

# %% [markdown]
# # What is Password Generator?
#
# A password generator creates **strong and random passwords**.
#
# It is useful for:
#
# * Security
# * Real-world applications

# %% [markdown]
# # Import Required Modules

# %%
import random
import string

# %% [markdown]
# # Step 1: Define Characters

# %%
letters = string.ascii_letters
digits = string.digits
symbols = string.punctuation

all_chars = letters + digits + symbols

# %% [markdown]
# # Step 2: Generate Password

# %%
length = 10

password = "".join(random.choice(all_chars) for _ in range(length))

print(password)
# Out:
# S2<wdt_xk;

# %% [markdown]
# # Step 3: User Input

# %%
length = int(input("Enter password length: "))

password = "".join(random.choice(all_chars) for _ in range(length))

print("Generated Password:", password)
# Out:
# Generated Password: >L,=d#:)

# %% [markdown]
# # Improved Version (Function)

# %%
def generate_password(length):
    return "".join(random.choice(all_chars) for _ in range(length))

print(generate_password(12))
# Out:
# PtJuoA"X?q/N

# %% [markdown]
# # Practice Enhancements
#
# Try to:
#
# * Ensure at least one digit and symbol
# * Add option for only letters
# * Add multiple password generation

# %% [markdown]
# # Summary
#
# In this notebook, we built:
#
# * A password generator
# * Used random and string modules
# * Created reusable function
#
# This is your first real mini project.
