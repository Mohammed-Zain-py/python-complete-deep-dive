# %% [markdown]
# # Python Complete Deep Dive
#
# ## Day 36 — OS Module and File System Operations
#
# In this notebook, we will cover:
#
# * What is OS module
# * Working with directories
# * Creating and removing folders
# * Listing files
# * Getting current working directory

# %% [markdown]
# # What is OS Module?
#
# The OS module allows us to **interact with the operating system**.
#
# It is used for:
#
# * File and folder operations
# * Path handling
# * Running system commands

# %% [markdown]
# # Importing OS Module

# %%
import os

# %% [markdown]
# # Current Working Directory

# %%
print(os.getcwd())
# Out:
# c:\Users\mdzai\Desktop\python-complete-deep-dive

# %% [markdown]
# # Listing Files and Folders

# %%
print(os.listdir())
# Out:
# ['.git', '01_python_intro.ipynb', '02_variables_datatypes.ipynb', '03_operators.ipynb', '04_input_output.ipynb', '05_strings.ipynb', '06_string_methods.ipynb', '07_conditionals.ipynb', '08_loops.ipynb', '09_loop_control.ipynb', '10_functions.ipynb', '11_function_arguments.ipynb', '12_lists.ipynb', '13_list_methods_comprehension.ipynb', '14_tuples.ipynb', '15_sets.ipynb', '16_dictionaries.ipynb', '17_string_formatting.ipynb', '18_recursion.ipynb', '19_exception_handling.ipynb', '20_file_handling.ipynb', '21_modules_imports.ipynb', '22_virtual_environment.ipynb', '23_oop_basics.ipynb', '24_constructors_self.ipynb', '25_inheritance.ipynb', '26_access_modifiers_class_static.ipynb', '27_decorators.ipynb', '28_generators.ipynb', '29_regex.ipynb', '30_threading_multiprocessing.ipynb', '31_lambda_map_filter_reduce.ipynb', '32_enumerate_zip.ipynb', '33_is_vs_equals.ipynb', '34_dir_help_introspection.ipynb', '35_main_dunder.ipynb', '36_os_module.ipynb', 'file1.py', 'sample.txt', 'test.txt', '_
# ...

# %% [markdown]
# # Creating a Directory

# %%
os.mkdir("test_folder")

# %% [markdown]
# # Removing a Directory

# %%
os.rmdir("test_folder")

# %% [markdown]
# # Changing Directory

# %%
os.chdir("..")
print(os.getcwd())
# Out:
# c:\Users\mdzai\Desktop

# %% [markdown]
# # Practice Problems'

# %%
# Problem 1: Print current directory

import os

print(os.getcwd())
# Out:
# c:\Users\mdzai\Desktop

# %%
# Problem 2: List all files

import os

print(os.listdir())
# Out:
# ['12 Java templates that solve DSA.pdf', '6th sem', '7th sem', 'Aicte_internship_project[1].docx', 'Anaconda', 'Aptitude', 'Asher Resume.pdf', 'Certificates', 'Data Science', 'Data Science Code with harry', 'desktop.ini', 'GitHub Desktop.lnk', 'Hi.docx', 'idcard-pavan.jpg', 'MAJOR_PROJECT_PPT1.pptx', 'Mandatory documents IBM .pdf', 'ml-scribe-folio-main.zip', 'Mohammed Asher Resume.pdf', 'Mohammed Asher.pdf', 'Mohammed_Zain_Resume_Developer.pdf', 'My Engineering markscards', 'MY SQL', 'My_projects', 'Opera Browser.lnk', 'Oracle SQL', 'pendrive memory', 'Project_report_MohammedZain.pdf', 'python-complete-deep-dive', 'reference resumes', 'SA2_V4_Grade 4_English_AS_Set A.pdf', 'StudentDetails.csv', 'Visual Studio Code.lnk', 'Zain Java', 'Zoom Workplace.lnk', '~$MAJOR_PROJECT_PPT1.pptx']

# %%
# Problem 3: Create a folder

import os

os.mkdir("demo_folder")

# %%
# Problem 4: Remove folder

import os

os.rmdir("demo_folder")

# %% [markdown]
# # Summary
#
# In this notebook, we learned:
#
# * OS module basics
# * File system operations
# * Directory handling
# * Practical examples
#
# This is very useful for automation and real-world projects.
