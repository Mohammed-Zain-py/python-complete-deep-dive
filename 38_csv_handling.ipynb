# %% [markdown]
# # Python Complete Deep Dive
#
# ## Day 38 — CSV Handling in Python
#
# In this notebook, we will cover:
#
# * What is CSV
# * csv module
# * Reading CSV files
# * Writing CSV files
# * Practical examples

# %% [markdown]
# # What is CSV?
#
# CSV (Comma Separated Values) is a file format used to store tabular data.
#
# Example:
#
# name,age
# Zain,21
# Ali,22

# %% [markdown]
# # Importing CSV Module

# %%
import csv

# %% [markdown]
# # Writing to CSV File

# %%
data = [
    ["name", "age"],
    ["Zain", 21],
    ["Ali", 22]
]

with open("data.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(data)

# %% [markdown]
# # Reading CSV File

# %%
with open("data.csv", "r") as file:
    reader = csv.reader(file)
    
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Zain', '21']
# ['Ali', '22']

# %% [markdown]
# # Using DictReader

# %%
with open("data.csv", "r") as file:
    reader = csv.DictReader(file)
    
    for row in reader:
        print(row)
# Out:
# {'name': 'Zain', 'age': '21'}
# {'name': 'Ali', 'age': '22'}

# %% [markdown]
# # Using DictWriter

# %%
with open("data2.csv", "w", newline="") as file:
    fieldnames = ["name", "age"]
    
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    
    writer.writeheader()
    writer.writerow({"name": "Zain", "age": 21})

# %% [markdown]
# # Practice Problems

# %%
# Problem 1: Write CSV file

import csv

with open("test.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["a", "b"])
    writer.writerow([1, 2])

# %%
# Problem 2: Read CSV file

import csv

with open("test.csv", "r") as file:
    for row in csv.reader(file):
        print(row)
# Out:
# ['a', 'b']
# ['1', '2']

# %%
# Problem 3: Use DictReader

import csv

with open("data.csv", "r") as file:
    reader = csv.DictReader(file)
    
    for row in reader:
        print(row["name"])
# Out:
# Zain
# Ali

# %% [markdown]
# # Summary
#
# In this notebook, we learned:
#
# * CSV file handling
# * Reading and writing CSV
# * DictReader and DictWriter
# * Practical examples
#
# CSV is very important for data analysis and real-world applications.
